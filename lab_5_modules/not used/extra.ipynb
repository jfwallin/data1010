# %%
from sklearn.datasets import make_moons, make_circles
from matplotlib import pyplot as plt

# %%
X, y = make_moons(n_samples=500, noise=0.1)
# #X, y = make_circles(n_samples=500, noise=0.05)

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap='bwr')

plt.show()

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp310-cp310-win_amd64.whl.metadata (4.6 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (25.9.23)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (2.0.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.76.0-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Using cached keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorflow) (2.2.6)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Using cached h5py-3.15.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Using cached optree-0.18.0-cp310-cp310-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2023.11.17)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (10.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.76.0-cp310-cp310-win_amd64.whl (4.7 MB)
# Using cached h5py-3.15.1-cp310-cp310-win_amd64.whl (2.9 MB)
# Using cached keras-3.12.0-py3-none-any.whl (1.5 MB)
# Using cached ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Using cached optree-0.18.0-cp310-cp310-win_amd64.whl (302 kB)
# Installing collected packages: optree, ml_dtypes, markdown, h5py, grpcio, google_pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 gast-0.6.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-3.12.0 markdown-3.10 ml_dtypes-0.5.4 optree-0.18.0 tensorboard-2.20.0 tensorflow-2.20.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\jfwal\anaconda3\envs\orbits\lib\site-packages)
