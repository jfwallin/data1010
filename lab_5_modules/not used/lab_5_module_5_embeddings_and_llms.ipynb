# %% [markdown]
# # Lab 5, Module 5: Prompting Foundations
#
# ### *Tying Embedding to LLM *
#
# **Estimated time: 15-20 minutes**
#
# 	-Try prompting in ChatGPT/Claude
# 	-Zero-shot, few-shot, chain-of-thought
# 	-Hallucination demo
# 	-Libraries: none
